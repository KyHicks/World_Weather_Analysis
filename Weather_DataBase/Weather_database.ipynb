# %%
# Create a new set of 2,000 random latitudes and longitudes.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
    
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key    

# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count}| {city}") 
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descrip = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                           "Current Description": city_weather_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1| bethel
# Processing Record 2 of Set 1| jamestown
# Processing Record 3 of Set 1| rikitea
# Processing Record 4 of Set 1| punta arenas
# Processing Record 5 of Set 1| terme
# Processing Record 6 of Set 1| pevek
# Processing Record 7 of Set 1| kaka
# Processing Record 8 of Set 1| mataura
# Processing Record 9 of Set 1| luderitz
# Processing Record 10 of Set 1| kapaa
# Processing Record 11 of Set 1| nome
# Processing Record 12 of Set 1| butaritari
# Processing Record 13 of Set 1| castro
# Processing Record 14 of Set 1| dwarka
# Processing Record 15 of Set 1| provideniya
# Processing Record 16 of Set 1| hilo
# Processing Record 17 of Set 1| te anau
# Processing Record 18 of Set 1| homer
# Processing Record 19 of Set 1| ushuaia
# Processing Record 20 of Set 1| yellowknife
# Processing Record 21 of Set 1| albany
# Processing Record 22 of Set 1| klyuchi
# Processing Record 23 of Set 1| husavik
# Processing Record 24 of Set 1| amderma
# City not found. Skipping...
# Processing Record 25 of Set 1| busselton
# Processing Record 26 of Set 1| bluff
# Processing Record 27 of Set 1| salalah
# Processing Record 28 of Set 1| nouadhibou
# Processing Record 29 of Set 1| kovernino
# Processing Record 30 of Set 1| ouadda
# Processing Record 31 of Set 1| attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1| tuktoyaktuk
# Processing Record 33 of Set 1| beatrice
# Processing Record 34 of Set 1| bengkulu
# Processing Record 35 of Set 1| cape town
# Processing Record 36 of Set 1| cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 1| khatanga
# Processing Record 38 of Set 1| broome
# Processing Record 39 of Set 1| partizanskoye
# Processing Record 40 of Set 1| atuona
# Processing Record 41 of Set 1| longyearbyen
# Processing Record 42 of Set 1| farafangana
# Processing Record 43 of Set 1| saint-philippe
# Processing Record 44 of Set 1| mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 1| karratha
# Processing Record 46 of Set 1| mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 1| meadow lake
# Processing Record 48 of Set 1| saint albans
# Processing Record 49 of Set 1| qaanaaq
# Processing Record 50 of Set 1| illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2| redea
# Processing Record 2 of Set 2| kutum
# Processing Record 3 of Set 2| katsuura
# Processing Record 4 of Set 2| sept-iles
# Processing Record 5 of Set 2| belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2| vestmannaeyjar
# Processing Record 7 of Set 2| tiksi
# Processing Record 8 of Set 2| georgetown
# Processing Record 9 of Set 2| ribeira grande
# Processing Record 10 of Set 2| hermanus
# Processing Record 11 of Set 2| kedougou
# Processing Record 12 of Set 2| thompson
# Processing Record 13 of Set 2| otavi
# Processing Record 14 of Set 2| vaini
# Processing Record 15 of Set 2| bredasdorp
# Processing Record 16 of Set 2| coquimbo
# Processing Record 17 of Set 2| fort nelson
# Processing Record 18 of Set 2| samusu
# City not found. Skipping...
# Processing Record 19 of Set 2| erenhot
# Processing Record 20 of Set 2| airai
# Processing Record 21 of Set 2| santa ana
# Processing Record 22 of Set 2| lebu
# Processing Record 23 of Set 2| fairbanks
# Processing Record 24 of Set 2| rimbey
# Processing Record 25 of Set 2| narsaq
# Processing Record 26 of Set 2| vila franca do campo
# Processing Record 27 of Set 2| dublin
# Processing Record 28 of Set 2| lebanon
# Processing Record 29 of Set 2| bandarbeyla
# Processing Record 30 of Set 2| rocha
# Processing Record 31 of Set 2| barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2| tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2| urengoy
# Processing Record 34 of Set 2| of
# City not found. Skipping...
# Processing Record 35 of Set 2| port alfred
# Processing Record 36 of Set 2| pesqueira
# Processing Record 37 of Set 2| temaraia
# City not found. Skipping...
# Processing Record 38 of Set 2| cascais
# Processing Record 39 of Set 2| kavieng
# Processing Record 40 of Set 2| vila velha
# Processing Record 41 of Set 2| lavrentiya
# Processing Record 42 of Set 2| osorio
# Processing Record 43 of Set 2| carnarvon
# Processing Record 44 of Set 2| batagay-alyta
# Processing Record 45 of Set 2| devrek
# Processing Record 46 of Set 2| deep river
# Processing Record 47 of Set 2| fukue
# Processing Record 48 of Set 2| roebourne
# Processing Record 49 of Set 2| thinadhoo
# Processing Record 50 of Set 2| puerto ayora
# Processing Record 1 of Set 3| haines junction
# Processing Record 2 of Set 3| mar del plata
# Processing Record 3 of Set 3| acapulco
# Processing Record 4 of Set 3| talnakh
# Processing Record 5 of Set 3| mahebourg
# Processing Record 6 of Set 3| road town
# Processing Record 7 of Set 3| teya
# Processing Record 8 of Set 3| fortuna
# Processing Record 9 of Set 3| burica
# City not found. Skipping...
# Processing Record 10 of Set 3| hobart
# Processing Record 11 of Set 3| port elizabeth
# Processing Record 12 of Set 3| vetluga
# Processing Record 13 of Set 3| lorengau
# Processing Record 14 of Set 3| hobyo
# Processing Record 15 of Set 3| hoquiam
# Processing Record 16 of Set 3| belaya gora
# Processing Record 17 of Set 3| hithadhoo
# Processing Record 18 of Set 3| aden
# Processing Record 19 of Set 3| vetlanda
# Processing Record 20 of Set 3| souillac
# Processing Record 21 of Set 3| codrington
# Processing Record 22 of Set 3| pangnirtung
# Processing Record 23 of Set 3| nova esperanca
# Processing Record 24 of Set 3| minsk
# Processing Record 25 of Set 3| laguna
# Processing Record 26 of Set 3| morehead
# Processing Record 27 of Set 3| marawi
# Processing Record 28 of Set 3| pitimbu
# Processing Record 29 of Set 3| la rioja
# Processing Record 30 of Set 3| caravelas
# Processing Record 31 of Set 3| manadhoo
# Processing Record 32 of Set 3| timra
# Processing Record 33 of Set 3| capitao poco
# Processing Record 34 of Set 3| rawson
# Processing Record 35 of Set 3| vardo
# Processing Record 36 of Set 3| ridgecrest
# Processing Record 37 of Set 3| egvekinot
# Processing Record 38 of Set 3| mehamn
# Processing Record 39 of Set 3| taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3| rio gallegos
# Processing Record 41 of Set 3| chuy
# Processing Record 42 of Set 3| yantal
# Processing Record 43 of Set 3| saskylakh
# Processing Record 44 of Set 3| karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 3| petropavlovsk-kamchatskiy
# Processing Record 46 of Set 3| srednekolymsk
# Processing Record 47 of Set 3| harper
# Processing Record 48 of Set 3| urumqi
# Processing Record 49 of Set 3| san patricio
# Processing Record 50 of Set 3| tasiilaq
# Processing Record 1 of Set 4| kurilsk
# Processing Record 2 of Set 4| nanortalik
# Processing Record 3 of Set 4| abu kamal
# Processing Record 4 of Set 4| arraial do cabo
# Processing Record 5 of Set 4| fergus falls
# Processing Record 6 of Set 4| turka
# Processing Record 7 of Set 4| iqaluit
# Processing Record 8 of Set 4| eureka
# Processing Record 9 of Set 4| sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4| tessalit
# Processing Record 11 of Set 4| mecca
# Processing Record 12 of Set 4| terre haute
# Processing Record 13 of Set 4| barra patuca
# Processing Record 14 of Set 4| ust-kuyga
# Processing Record 15 of Set 4| saleaula
# City not found. Skipping...
# Processing Record 16 of Set 4| parkersburg
# Processing Record 17 of Set 4| nuevo progreso
# Processing Record 18 of Set 4| bardiyah
# Processing Record 19 of Set 4| wanning
# Processing Record 20 of Set 4| nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4| sao joao da barra
# Processing Record 22 of Set 4| gillingham
# Processing Record 23 of Set 4| barrow
# Processing Record 24 of Set 4| mount isa
# Processing Record 25 of Set 4| baykit
# Processing Record 26 of Set 4| san carlos de bariloche
# Processing Record 27 of Set 4| machilipatnam
# Processing Record 28 of Set 4| new norfolk
# Processing Record 29 of Set 4| hasaki
# Processing Record 30 of Set 4| sistranda
# Processing Record 31 of Set 4| stornoway
# Processing Record 32 of Set 4| evensk
# Processing Record 33 of Set 4| borba
# Processing Record 34 of Set 4| esmeraldas
# Processing Record 35 of Set 4| suicheng
# Processing Record 36 of Set 4| kalmunai
# Processing Record 37 of Set 4| delta del tigre
# Processing Record 38 of Set 4| pietersburg
# Processing Record 39 of Set 4| kodiak
# Processing Record 40 of Set 4| balykshi
# Processing Record 41 of Set 4| rodez
# Processing Record 42 of Set 4| tombouctou
# Processing Record 43 of Set 4| berbera
# Processing Record 44 of Set 4| port lincoln
# Processing Record 45 of Set 4| rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 4| esperance
# Processing Record 47 of Set 4| nova londrina
# Processing Record 48 of Set 4| mackay
# Processing Record 49 of Set 4| khorixas
# Processing Record 50 of Set 4| sungaipenuh
# Processing Record 1 of Set 5| faanui
# Processing Record 2 of Set 5| louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 5| norman wells
# Processing Record 4 of Set 5| kuytun
# Processing Record 5 of Set 5| liwale
# Processing Record 6 of Set 5| lauchhammer
# Processing Record 7 of Set 5| neiafu
# Processing Record 8 of Set 5| gujar khan
# Processing Record 9 of Set 5| sabinas
# Processing Record 10 of Set 5| hirara
# Processing Record 11 of Set 5| halifax
# Processing Record 12 of Set 5| krasnorechenskiy
# Processing Record 13 of Set 5| boueni
# Processing Record 14 of Set 5| madison
# Processing Record 15 of Set 5| cayenne
# Processing Record 16 of Set 5| calderitas
# Processing Record 17 of Set 5| rungata
# City not found. Skipping...
# Processing Record 18 of Set 5| karoi
# Processing Record 19 of Set 5| belebey
# Processing Record 20 of Set 5| adrar
# Processing Record 21 of Set 5| kaeo
# Processing Record 22 of Set 5| ponta do sol
# Processing Record 23 of Set 5| utiroa
# City not found. Skipping...
# Processing Record 24 of Set 5| pandamatenga
# Processing Record 25 of Set 5| khorion
# City not found. Skipping...
# Processing Record 26 of Set 5| port-gentil
# Processing Record 27 of Set 5| hamilton
# Processing Record 28 of Set 5| torbay
# Processing Record 29 of Set 5| nhamunda
# Processing Record 30 of Set 5| sitka
# Processing Record 31 of Set 5| dumas
# Processing Record 32 of Set 5| nelson bay
# Processing Record 33 of Set 5| biltine
# Processing Record 34 of Set 5| altamira
# Processing Record 35 of Set 5| margate
# Processing Record 36 of Set 5| ust-kulom
# Processing Record 37 of Set 5| weyburn
# Processing Record 38 of Set 5| saint george
# Processing Record 39 of Set 5| kedainiai
# Processing Record 40 of Set 5| surt
# Processing Record 41 of Set 5| padang
# Processing Record 42 of Set 5| huarmey
# Processing Record 43 of Set 5| ternate
# Processing Record 44 of Set 5| ancud
# Processing Record 45 of Set 5| kitimat
# Processing Record 46 of Set 5| tereze
# Processing Record 47 of Set 5| honiara
# Processing Record 48 of Set 5| elko
# Processing Record 49 of Set 5| moyale
# Processing Record 50 of Set 5| pimenteiras
# Processing Record 1 of Set 6| ozuluama
# Processing Record 2 of Set 6| fetesti
# Processing Record 3 of Set 6| port macquarie
# Processing Record 4 of Set 6| raga
# Processing Record 5 of Set 6| moose factory
# Processing Record 6 of Set 6| berlevag
# Processing Record 7 of Set 6| meulaboh
# Processing Record 8 of Set 6| cuamba
# Processing Record 9 of Set 6| tommot
# Processing Record 10 of Set 6| redlands
# Processing Record 11 of Set 6| inirida
# Processing Record 12 of Set 6| vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 6| viksoyri
# City not found. Skipping...
# Processing Record 14 of Set 6| sangar
# Processing Record 15 of Set 6| linxia
# Processing Record 16 of Set 6| vysha
# Processing Record 17 of Set 6| vaitape
# Processing Record 18 of Set 6| tilichiki
# Processing Record 19 of Set 6| asau
# Processing Record 20 of Set 6| port hardy
# Processing Record 21 of Set 6| ilulissat
# Processing Record 22 of Set 6| ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 6| krasnoselkup
# Processing Record 24 of Set 6| kamenka
# Processing Record 25 of Set 6| chirongui
# Processing Record 26 of Set 6| san quintin
# Processing Record 27 of Set 6| cuenca
# Processing Record 28 of Set 6| coihaique
# Processing Record 29 of Set 6| turbat
# Processing Record 30 of Set 6| fenoarivo
# Processing Record 31 of Set 6| cherskiy
# Processing Record 32 of Set 6| telimele
# Processing Record 33 of Set 6| camocim
# Processing Record 34 of Set 6| kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 6| wanaka
# Processing Record 36 of Set 6| oyama
# Processing Record 37 of Set 6| mapimi
# Processing Record 38 of Set 6| warqla
# City not found. Skipping...
# Processing Record 39 of Set 6| kaitangata
# Processing Record 40 of Set 6| avarua
# Processing Record 41 of Set 6| aksu
# Processing Record 42 of Set 6| henties bay
# Processing Record 43 of Set 6| chalus
# Processing Record 44 of Set 6| hualmay
# Processing Record 45 of Set 6| iskateley
# Processing Record 46 of Set 6| vestmanna
# Processing Record 47 of Set 6| bulalacao
# Processing Record 48 of Set 6| sukhumi
# Processing Record 49 of Set 6| anadyr
# Processing Record 50 of Set 6| axim
# Processing Record 1 of Set 7| bonthe
# Processing Record 2 of Set 7| gadung
# Processing Record 3 of Set 7| prince rupert
# Processing Record 4 of Set 7| miraflores
# Processing Record 5 of Set 7| cabo san lucas
# Processing Record 6 of Set 7| vostok
# Processing Record 7 of Set 7| fernie
# Processing Record 8 of Set 7| dilla
# Processing Record 9 of Set 7| ituni
# City not found. Skipping...
# Processing Record 10 of Set 7| seminole
# Processing Record 11 of Set 7| victoria
# Processing Record 12 of Set 7| rettikhovka
# Processing Record 13 of Set 7| grand gaube
# Processing Record 14 of Set 7| huilong
# Processing Record 15 of Set 7| samarai
# Processing Record 16 of Set 7| tukrah
# Processing Record 17 of Set 7| chokurdakh
# Processing Record 18 of Set 7| nikolskoye
# Processing Record 19 of Set 7| faya
# Processing Record 20 of Set 7| biloela
# Processing Record 21 of Set 7| banmo
# City not found. Skipping...
# Processing Record 22 of Set 7| san-pedro
# Processing Record 23 of Set 7| san antonio
# Processing Record 24 of Set 7| east london
# Processing Record 25 of Set 7| phrai bung
# City not found. Skipping...
# Processing Record 26 of Set 7| kaihua
# Processing Record 27 of Set 7| sorland
# Processing Record 28 of Set 7| taoudenni
# Processing Record 29 of Set 7| beringovskiy
# Processing Record 30 of Set 7| chagda
# City not found. Skipping...
# Processing Record 31 of Set 7| chiang khong
# Processing Record 32 of Set 7| aksarka
# Processing Record 33 of Set 7| port moresby
# Processing Record 34 of Set 7| dikson
# Processing Record 35 of Set 7| deputatskiy
# Processing Record 36 of Set 7| klaksvik
# Processing Record 37 of Set 7| matay
# Processing Record 38 of Set 7| pemangkat
# Processing Record 39 of Set 7| ixtapa
# Processing Record 40 of Set 7| kenai
# Processing Record 41 of Set 7| hit
# Processing Record 42 of Set 7| pacific grove
# Processing Record 43 of Set 7| cockburn town
# Processing Record 44 of Set 7| kruisfontein
# Processing Record 45 of Set 7| jalingo
# Processing Record 46 of Set 7| tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7| tuatapere
# Processing Record 48 of Set 7| pachino
# Processing Record 49 of Set 7| olovyannaya
# Processing Record 50 of Set 7| arlit
# Processing Record 1 of Set 8| hami
# Processing Record 2 of Set 8| basco
# Processing Record 3 of Set 8| sikasso
# Processing Record 4 of Set 8| atar
# Processing Record 5 of Set 8| beloha
# Processing Record 6 of Set 8| talara
# Processing Record 7 of Set 8| galle
# Processing Record 8 of Set 8| matamoros
# Processing Record 9 of Set 8| bud
# Processing Record 10 of Set 8| kadirli
# Processing Record 11 of Set 8| lasa
# Processing Record 12 of Set 8| pisco
# Processing Record 13 of Set 8| luangwa
# Processing Record 14 of Set 8| mahanoro
# Processing Record 15 of Set 8| sao filipe
# Processing Record 16 of Set 8| srandakan
# Processing Record 17 of Set 8| northport
# Processing Record 18 of Set 8| afyonkarahisar
# Processing Record 19 of Set 8| dagua
# Processing Record 20 of Set 8| kloulklubed
# Processing Record 21 of Set 8| zyryanka
# Processing Record 22 of Set 8| mana
# Processing Record 23 of Set 8| gawler
# Processing Record 24 of Set 8| ahipara
# Processing Record 25 of Set 8| kamennogorsk
# Processing Record 26 of Set 8| myaundzha
# Processing Record 27 of Set 8| san andres
# Processing Record 28 of Set 8| presidente dutra
# Processing Record 29 of Set 8| alice springs
# Processing Record 30 of Set 8| csanadpalota
# Processing Record 31 of Set 8| oranjemund
# Processing Record 32 of Set 8| tura
# Processing Record 33 of Set 8| muros
# Processing Record 34 of Set 8| ranong
# Processing Record 35 of Set 8| portland
# Processing Record 36 of Set 8| guanare
# Processing Record 37 of Set 8| constitucion
# Processing Record 38 of Set 8| grindavik
# Processing Record 39 of Set 8| urucara
# Processing Record 40 of Set 8| ivanteyevka
# Processing Record 41 of Set 8| havelock
# Processing Record 42 of Set 8| tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 8| pimenta bueno
# Processing Record 44 of Set 8| pochutla
# Processing Record 45 of Set 8| chauk
# Processing Record 46 of Set 8| kununurra
# Processing Record 47 of Set 8| phalombe
# Processing Record 48 of Set 8| upernavik
# Processing Record 49 of Set 8| piopio
# Processing Record 50 of Set 8| sakakah
# Processing Record 1 of Set 9| new haven
# Processing Record 2 of Set 9| labrea
# Processing Record 3 of Set 9| liuzhou
# Processing Record 4 of Set 9| lukovetskiy
# Processing Record 5 of Set 9| paamiut
# Processing Record 6 of Set 9| nazas
# Processing Record 7 of Set 9| marsa matruh
# Processing Record 8 of Set 9| sur
# Processing Record 9 of Set 9| marsh harbour
# Processing Record 10 of Set 9| koster
# Processing Record 11 of Set 9| saint-francois
# Processing Record 12 of Set 9| atasu
# Processing Record 13 of Set 9| launceston
# Processing Record 14 of Set 9| sao joaquim
# Processing Record 15 of Set 9| samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 9| ghanzi
# Processing Record 17 of Set 9| san francisco
# Processing Record 18 of Set 9| santa maria
# Processing Record 19 of Set 9| gorgan
# Processing Record 20 of Set 9| dharchula
# Processing Record 21 of Set 9| tongsa
# City not found. Skipping...
# Processing Record 22 of Set 9| podporozhye
# Processing Record 23 of Set 9| quatre cocos
# Processing Record 24 of Set 9| middleton
# Processing Record 25 of Set 9| rio cuarto
# Processing Record 26 of Set 9| saldanha
# Processing Record 27 of Set 9| derzhavinsk
# Processing Record 28 of Set 9| alexandria
# Processing Record 29 of Set 9| alofi
# Processing Record 30 of Set 9| pithoragarh
# Processing Record 31 of Set 9| havre
# Processing Record 32 of Set 9| flinders
# Processing Record 33 of Set 9| harbour breton
# Processing Record 34 of Set 9| tupiza
# Processing Record 35 of Set 9| micheweni
# Processing Record 36 of Set 9| general roca
# Processing Record 37 of Set 9| tadine
# Processing Record 38 of Set 9| chapais
# Processing Record 39 of Set 9| kulhudhuffushi
# Processing Record 40 of Set 9| manokwari
# Processing Record 41 of Set 9| puerto carreno
# Processing Record 42 of Set 9| porto belo
# Processing Record 43 of Set 9| neuquen
# Processing Record 44 of Set 9| los llanos de aridane
# Processing Record 45 of Set 9| bambous virieux
# Processing Record 46 of Set 9| khonsa
# Processing Record 47 of Set 9| abilene
# Processing Record 48 of Set 9| poum
# Processing Record 49 of Set 9| severo-yeniseyskiy
# Processing Record 50 of Set 9| mandan
# Processing Record 1 of Set 10| gillette
# Processing Record 2 of Set 10| bathsheba
# Processing Record 3 of Set 10| korce
# Processing Record 4 of Set 10| los lunas
# Processing Record 5 of Set 10| nuuk
# Processing Record 6 of Set 10| cabedelo
# Processing Record 7 of Set 10| vuktyl
# Processing Record 8 of Set 10| werda
# Processing Record 9 of Set 10| touros
# Processing Record 10 of Set 10| minab
# Processing Record 11 of Set 10| hunza
# City not found. Skipping...
# Processing Record 12 of Set 10| seoul
# Processing Record 13 of Set 10| vitim
# Processing Record 14 of Set 10| ewo
# Processing Record 15 of Set 10| san ignacio
# Processing Record 16 of Set 10| leningradskiy
# Processing Record 17 of Set 10| mandalgovi
# Processing Record 18 of Set 10| dingle
# Processing Record 19 of Set 10| mount darwin
# Processing Record 20 of Set 10| yulara
# Processing Record 21 of Set 10| sivaki
# Processing Record 22 of Set 10| stockbridge
# Processing Record 23 of Set 10| kattivakkam
# Processing Record 24 of Set 10| sumenep
# Processing Record 25 of Set 10| togur
# Processing Record 26 of Set 10| aklavik
# Processing Record 27 of Set 10| fort-shevchenko
# Processing Record 28 of Set 10| hailar
# Processing Record 29 of Set 10| mrirt
# City not found. Skipping...
# Processing Record 30 of Set 10| cabras
# Processing Record 31 of Set 10| oussouye
# Processing Record 32 of Set 10| nabire
# Processing Record 33 of Set 10| champerico
# Processing Record 34 of Set 10| thai binh
# Processing Record 35 of Set 10| estevan
# Processing Record 36 of Set 10| ukholovo
# Processing Record 37 of Set 10| qasigiannguit
# Processing Record 38 of Set 10| marcona
# City not found. Skipping...
# Processing Record 39 of Set 10| cidreira
# Processing Record 40 of Set 10| novikovo
# Processing Record 41 of Set 10| oka
# Processing Record 42 of Set 10| ughelli
# Processing Record 43 of Set 10| luwingu
# Processing Record 44 of Set 10| tazovskiy
# Processing Record 45 of Set 10| presidencia roque saenz pena
# Processing Record 46 of Set 10| college
# Processing Record 47 of Set 10| guane
# Processing Record 48 of Set 10| rio grande
# Processing Record 49 of Set 10| sola
# Processing Record 50 of Set 10| abu dhabi
# Processing Record 1 of Set 11| kieta
# Processing Record 2 of Set 11| lazurne
# Processing Record 3 of Set 11| katha
# City not found. Skipping...
# Processing Record 4 of Set 11| kerki
# City not found. Skipping...
# Processing Record 5 of Set 11| beira
# Processing Record 6 of Set 11| odweyne
# Processing Record 7 of Set 11| santiago de cao
# Processing Record 8 of Set 11| jiayuguan
# Processing Record 9 of Set 11| nyurba
# Processing Record 10 of Set 11| komsomolskiy
# Processing Record 11 of Set 11| puerto madero
# Processing Record 12 of Set 11| nishihara
# Processing Record 13 of Set 11| zeya
# Processing Record 14 of Set 11| bargal
# City not found. Skipping...
# Processing Record 15 of Set 11| bharatpur
# Processing Record 16 of Set 11| mudbidri
# Processing Record 17 of Set 11| namibe
# Processing Record 18 of Set 11| gayeri
# Processing Record 19 of Set 11| dokka
# Processing Record 20 of Set 11| tabora
# Processing Record 21 of Set 11| beckley
# Processing Record 22 of Set 11| jacareacanga
# Processing Record 23 of Set 11| lesnoy
# Processing Record 24 of Set 11| americo brasiliense
# Processing Record 25 of Set 11| turukhansk
# Processing Record 26 of Set 11| saint-joseph
# Processing Record 27 of Set 11| srem
# Processing Record 28 of Set 11| khomutovka
# Processing Record 29 of Set 11| guerrero negro
# Processing Record 30 of Set 11| oshikango
# Processing Record 31 of Set 11| mogzon
# Processing Record 32 of Set 11| pangody
# Processing Record 33 of Set 11| port hawkesbury
# Processing Record 34 of Set 11| tateyama
# Processing Record 35 of Set 11| katobu
# Processing Record 36 of Set 11| san jose
# Processing Record 37 of Set 11| puerto escondido
# Processing Record 38 of Set 11| toliary
# City not found. Skipping...
# Processing Record 39 of Set 11| mayo
# Processing Record 40 of Set 11| palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 11| adwa
# Processing Record 42 of Set 11| podstepki
# Processing Record 43 of Set 11| myski
# Processing Record 44 of Set 11| west plains
# Processing Record 45 of Set 11| pala
# Processing Record 46 of Set 11| otofuke
# Processing Record 47 of Set 11| shakawe
# Processing Record 48 of Set 11| sassandra
# Processing Record 49 of Set 11| lompoc
# Processing Record 50 of Set 11| berberati
# Processing Record 1 of Set 12| rognan
# Processing Record 2 of Set 12| big spring
# Processing Record 3 of Set 12| bubaque
# Processing Record 4 of Set 12| warwick
# Processing Record 5 of Set 12| lazaro cardenas
# Processing Record 6 of Set 12| hukuntsi
# Processing Record 7 of Set 12| aflu
# City not found. Skipping...
# Processing Record 8 of Set 12| stepnogorsk
# Processing Record 9 of Set 12| alta floresta
# Processing Record 10 of Set 12| kautokeino
# Processing Record 11 of Set 12| belyy yar
# Processing Record 12 of Set 12| oudtshoorn
# Processing Record 13 of Set 12| noumea
# Processing Record 14 of Set 12| marquette
# Processing Record 15 of Set 12| qostanay
# Processing Record 16 of Set 12| lagoa
# Processing Record 17 of Set 12| baker city
# Processing Record 18 of Set 12| oktyabrskiy
# Processing Record 19 of Set 12| vreed en hoop
# City not found. Skipping...
# Processing Record 20 of Set 12| iralaya
# Processing Record 21 of Set 12| ishigaki
# Processing Record 22 of Set 12| slave lake
# Processing Record 23 of Set 12| vilyuysk
# Processing Record 24 of Set 12| gladstone
# Processing Record 25 of Set 12| dunedin
# Processing Record 26 of Set 12| mairi
# Processing Record 27 of Set 12| palora
# Processing Record 28 of Set 12| rexburg
# Processing Record 29 of Set 12| radovitskiy
# Processing Record 30 of Set 12| archidona
# Processing Record 31 of Set 12| port blair
# Processing Record 32 of Set 12| cap malheureux
# Processing Record 33 of Set 12| tual
# Processing Record 34 of Set 12| abalak
# Processing Record 35 of Set 12| san cristobal
# Processing Record 36 of Set 12| jiazi
# Processing Record 37 of Set 12| cantu
# Processing Record 38 of Set 12| makakilo city
# Processing Record 39 of Set 12| mount gambier
# Processing Record 40 of Set 12| mehriz
# Processing Record 41 of Set 12| baruun-urt
# Processing Record 42 of Set 12| muravlenko
# Processing Record 43 of Set 12| imbituba
# Processing Record 44 of Set 12| ibra
# Processing Record 45 of Set 12| okaihau
# Processing Record 46 of Set 12| kysyl-syr
# Processing Record 47 of Set 12| ondangwa
# Processing Record 48 of Set 12| clearwater
# Processing Record 49 of Set 12| hambantota
# Processing Record 50 of Set 12| zhangye
# Processing Record 1 of Set 13| kolondieba
# Processing Record 2 of Set 13| maldonado
# Processing Record 3 of Set 13| hanna
# Processing Record 4 of Set 13| namtsy
# Processing Record 5 of Set 13| bertogne
# Processing Record 6 of Set 13| zhmerynka
# Processing Record 7 of Set 13| koundara
# Processing Record 8 of Set 13| camana
# Processing Record 9 of Set 13| balakovo
# Processing Record 10 of Set 13| jizan
# Processing Record 11 of Set 13| oistins
# Processing Record 12 of Set 13| norrtalje
# Processing Record 13 of Set 13| emba
# Processing Record 14 of Set 13| jumla
# Processing Record 15 of Set 13| kilindoni
# Processing Record 16 of Set 13| goundam
# Processing Record 17 of Set 13| gat
# Processing Record 18 of Set 13| kargasok
# Processing Record 19 of Set 13| tondano
# Processing Record 20 of Set 13| izumo
# Processing Record 21 of Set 13| ostrovskoye
# Processing Record 22 of Set 13| omboue
# Processing Record 23 of Set 13| waipawa
# Processing Record 24 of Set 13| shingu
# Processing Record 25 of Set 13| jijiga
# Processing Record 26 of Set 13| port hedland
# Processing Record 27 of Set 13| urulga
# City not found. Skipping...
# Processing Record 28 of Set 13| ondjiva
# Processing Record 29 of Set 13| xuchang
# Processing Record 30 of Set 13| ketchikan
# Processing Record 31 of Set 13| kahului
# Processing Record 32 of Set 13| vidim
# Processing Record 33 of Set 13| purpe
# Processing Record 34 of Set 13| praya
# Processing Record 35 of Set 13| awbari
# Processing Record 36 of Set 13| tsumeb
# Processing Record 37 of Set 13| langres
# Processing Record 38 of Set 13| zhezkazgan
# Processing Record 39 of Set 13| shumskiy
# Processing Record 40 of Set 13| zambezi
# Processing Record 41 of Set 13| eufaula
# Processing Record 42 of Set 13| strezhevoy
# Processing Record 43 of Set 13| clyde river
# Processing Record 44 of Set 13| gamba
# Processing Record 45 of Set 13| balakhninskiy
# Processing Record 46 of Set 13| krynychky
# Processing Record 47 of Set 13| takoradi
# Processing Record 48 of Set 13| ukiah
# Processing Record 49 of Set 13| port augusta
# Processing Record 50 of Set 13| tragana
# Processing Record 1 of Set 14| gravdal
# Processing Record 2 of Set 14| tselinnoye
# Processing Record 3 of Set 14| naze
# Processing Record 4 of Set 14| kemijarvi
# Processing Record 5 of Set 14| lavumisa
# Processing Record 6 of Set 14| kamakhyanagar
# Processing Record 7 of Set 14| acari
# Processing Record 8 of Set 14| lovington
# Processing Record 9 of Set 14| east brainerd
# Processing Record 10 of Set 14| ucluelet
# Processing Record 11 of Set 14| greystones
# Processing Record 12 of Set 14| teruel
# Processing Record 13 of Set 14| inzer
# Processing Record 14 of Set 14| alyangula
# Processing Record 15 of Set 14| ayacucho
# Processing Record 16 of Set 14| ndele
# Processing Record 17 of Set 14| torrington
# Processing Record 18 of Set 14| ialibu
# Processing Record 19 of Set 14| buraydah
# Processing Record 20 of Set 14| sampit
# Processing Record 21 of Set 14| umm lajj
# Processing Record 22 of Set 14| nandu
# Processing Record 23 of Set 14| nhulunbuy
# Processing Record 24 of Set 14| gazion
# City not found. Skipping...
# Processing Record 25 of Set 14| grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 14| bari
# Processing Record 27 of Set 14| ust-nera
# Processing Record 28 of Set 14| ichinohe
# Processing Record 29 of Set 14| maceio
# Processing Record 30 of Set 14| ostrovnoy
# Processing Record 31 of Set 14| opuwo
# Processing Record 32 of Set 14| rosarito
# Processing Record 33 of Set 14| tongchuan
# Processing Record 34 of Set 14| itarema
# Processing Record 35 of Set 14| port-cartier
# Processing Record 36 of Set 14| aykhal
# Processing Record 37 of Set 14| awjilah
# Processing Record 38 of Set 14| sahrak
# City not found. Skipping...
# Processing Record 39 of Set 14| la ronge
# Processing Record 40 of Set 14| ulladulla
# Processing Record 41 of Set 14| monywa
# Processing Record 42 of Set 14| le vauclin
# Processing Record 43 of Set 14| keti bandar
# Processing Record 44 of Set 14| jalu
# Processing Record 45 of Set 14| muisne
# Processing Record 46 of Set 14| vicuna
# Processing Record 47 of Set 14| olafsvik
# Processing Record 48 of Set 14| campoverde
# Processing Record 49 of Set 14| dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 14| alekseyevsk
# Processing Record 1 of Set 15| kompaniyivka
# Processing Record 2 of Set 15| necochea
# Processing Record 3 of Set 15| terre-de-bas
# Processing Record 4 of Set 15| coruripe
# Processing Record 5 of Set 15| borovskoy
# Processing Record 6 of Set 15| shimoda
# Processing Record 7 of Set 15| cozumel
# Processing Record 8 of Set 15| canmore
# Processing Record 9 of Set 15| harlingen
# Processing Record 10 of Set 15| winchester
# Processing Record 11 of Set 15| shirokiy
# Processing Record 12 of Set 15| mundo nuevo
# Processing Record 13 of Set 15| hofn
# Processing Record 14 of Set 15| ulles
# Processing Record 15 of Set 15| mahibadhoo
# Processing Record 16 of Set 15| oyotun
# Processing Record 17 of Set 15| marystown
# Processing Record 18 of Set 15| mocuba
# Processing Record 19 of Set 15| tabialan
# City not found. Skipping...
# Processing Record 20 of Set 15| aginskoye
# Processing Record 21 of Set 15| paulista
# Processing Record 22 of Set 15| flin flon
# Processing Record 23 of Set 15| camacha
# Processing Record 24 of Set 15| letlhakane
# Processing Record 25 of Set 15| maniitsoq
# Processing Record 26 of Set 15| praia da vitoria
# Processing Record 27 of Set 15| severo-kurilsk
# Processing Record 28 of Set 15| honningsvag
# Processing Record 29 of Set 15| la grande
# Processing Record 30 of Set 15| roma
# Processing Record 31 of Set 15| tiznit
# Processing Record 32 of Set 15| pilar
# Processing Record 33 of Set 15| leshukonskoye
# Processing Record 34 of Set 15| shiloh
# Processing Record 35 of Set 15| walvis bay
# Processing Record 36 of Set 15| lakes entrance
# Processing Record 37 of Set 15| kuche
# City not found. Skipping...
# Processing Record 38 of Set 15| babanusah
# City not found. Skipping...
# Processing Record 39 of Set 15| tucuma
# Processing Record 40 of Set 15| moron
# Processing Record 41 of Set 15| gudari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bethel  41.3712  -73.4140     22.50        56           0
# 1     Jamestown  42.0970  -79.2353     18.72        60         100
# 2       Rikitea -23.1203 -134.9692     76.86        70         100
# 3  Punta Arenas -53.1500  -70.9167     50.11        57          75
# 4         Terme  41.2092   36.9739     46.33        73          94
# 5         Pevek  69.7008  170.3133    -15.70        97          96
# 6          Kaka  37.3482   59.6143     39.52        63           0
# 7       Mataura -46.1927  168.8643     73.99        58          46
# 8      Luderitz -26.6481   15.1594     64.76        87          65
# 9         Kapaa  22.0752 -159.3190     80.47        63           0
#
#    Wind Speed Country Current Description
# 0        3.44      US           clear sky
# 1        0.00      US     overcast clouds
# 2        5.06      PF     overcast clouds
# 3       26.46      CL       broken clouds
# 4        4.27      TR          light rain
# 5        2.19      RU     overcast clouds
# 6        4.99      TM           clear sky
# 7        1.70      NZ    scattered clouds
# 8        9.51      NA       broken clouds
# 9        1.99      US           clear sky

# %%
# Reorder the columns as city, country, date, lat, lng, max temp, humidity, cloudiness, and wind speed.

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bethel      US  41.3712  -73.4140     22.50        56           0
# 1     Jamestown      US  42.0970  -79.2353     18.72        60         100
# 2       Rikitea      PF -23.1203 -134.9692     76.86        70         100
# 3  Punta Arenas      CL -53.1500  -70.9167     50.11        57          75
# 4         Terme      TR  41.2092   36.9739     46.33        73          94
# 5         Pevek      RU  69.7008  170.3133    -15.70        97          96
# 6          Kaka      TM  37.3482   59.6143     39.52        63           0
# 7       Mataura      NZ -46.1927  168.8643     73.99        58          46
# 8      Luderitz      NA -26.6481   15.1594     64.76        87          65
# 9         Kapaa      US  22.0752 -159.3190     80.47        63           0
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1        0.00     overcast clouds
# 2        5.06     overcast clouds
# 3       26.46       broken clouds
# 4        4.27          light rain
# 5        2.19     overcast clouds
# 6        4.99           clear sky
# 7        1.70    scattered clouds
# 8        9.51       broken clouds
# 9        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
